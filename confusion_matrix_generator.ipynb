# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# # Signorino Model

# %% [markdown]
# ## Balanced Dataset: L=1

# %%
conf_matrix = np.array([
 [0, 5, 0, 0, 0, 0, 1],
 [0, 78, 0, 0, 0, 0, 21],
 [0, 42, 0, 0, 0, 1, 13],
 [3, 70, 0, 0, 0, 0, 26],
 [0, 71, 0, 0, 0, 2, 26],
 [7, 64, 0, 0, 0, 1, 27],
 [0, 74, 0, 0, 0, 0, 25]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Signorino Model\nLambda1 = 1 | Lambda2 = 1 | Accuracy = 0.1796")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Balanced Dataset: L=0.5

# %%
conf_matrix = np.array([
 [0, 5, 0, 0, 0, 0, 1],
 [0, 90, 0, 0, 0, 0, 9],
 [0, 52, 0, 0, 0, 0, 4],
 [0, 88, 0, 0, 0, 0, 11],
 [0, 91, 0, 0, 0, 3, 5],
 [0, 81, 0, 0, 0, 1, 17],
 [0, 92, 0, 0, 0, 0, 7]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Signorino Model\nLambda1 = 0.5 | Lambda2 = 0.5 | Accuracy = 0.1693")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Balanced Dataset: L=2

# %%
conf_matrix = np.array([
 [0, 5, 0, 0, 0, 0, 1],
 [7, 70, 0, 0, 0, 1, 21],
 [1, 35, 0, 0, 1, 2, 17],
 [10, 59, 0, 0, 0, 1, 29],
 [6, 56, 0, 0, 2, 2, 33],
 [15, 48, 0, 0, 2, 1, 33],
 [3, 59, 0, 0, 2, 2, 33]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Signorino Model\nLambda1 = 2 | Lambda2 = 2 | Accuracy = 0.1831")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Balanced Dataset: L=0.1

# %%
conf_matrix = np.array([
 [0, 6, 0, 0, 0, 0, 0],
 [0, 99, 0, 0, 0, 0, 0],
 [0, 56, 0, 0, 0, 0, 0],
 [0, 99, 0, 0, 0, 0, 0],
 [0, 97, 0, 0, 0, 2, 0],
 [0, 98, 0, 0, 0, 1, 0],
 [0, 99, 0, 0, 0, 0, 0]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Signorino Model\nLambda1 = 0.1 | Lambda2 = 0.1 | Accuracy = 0.1727")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Balanced Dataset: L=10

# %%
conf_matrix = np.array([
 [0, 4, 0, 0, 2, 0, 0],
 [6, 29, 0, 0, 43, 16, 5],
 [5, 15, 0, 0, 23, 4, 9],
 [7, 24, 0, 0, 46, 12, 10],
 [9, 24, 0, 0, 36, 18, 12],
 [15, 16, 0, 0, 42, 16, 10],
 [3, 24, 0, 0, 43, 12, 17]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Signorino Model\nLambda1 = 10 | Lambda2 = 10 | Accuracy = 0.1693")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %%
conf_matrix = np.array([
 [0, 2, 0, 0, 0, 4, 0],
 [0, 52, 0, 0, 0, 47, 0],
 [0, 27, 0, 0, 0, 29, 0],
 [0, 40, 0, 0, 0, 59, 0],
 [0, 49, 0, 0, 0, 50, 0],
 [0, 42, 0, 0, 0, 57, 0],
 [0, 47, 0, 0, 0, 52, 0]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Signorino Model\nLambda1 = 0.0001 | Lambda2 = 0.0001 | Accuracy = 0.1883")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Quantum-Like Signorino Model

# %% [markdown]
# ## Balanced Dataset: L=1

# %%
conf_matrix = np.array([
 [0, 2, 2, 0, 0, 0, 2],
 [0, 52, 2, 0, 0, 24, 21],
 [0, 18, 6, 0, 0, 12, 20],
 [0, 45, 3, 0, 0, 27, 24],
 [0, 26, 7, 0, 0, 39, 27],
 [0, 27, 4, 0, 0, 41, 27],
 [0, 38, 4, 0, 0, 32, 25]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 1 | Lambda2 = 1 | Accuracy = 0.2142")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Balanced Dataset: L=0.5

# %%
conf_matrix = np.array([
 [0, 3, 2, 0, 0, 1, 0],
 [0, 68, 0, 0, 0, 28, 3],
 [0, 32, 6, 0, 0, 16, 2],
 [0, 58, 1, 0, 0, 39, 1],
 [0, 36, 7, 0, 0, 52, 4],
 [0, 41, 3, 0, 0, 53, 2],
 [0, 54, 6, 0, 0, 33, 6]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 0.5 | Lambda2 = 0.5 | Accuracy = 0.2297")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Balanced Dataset: L=2

# %%
conf_matrix = np.array([
 [0, 0, 3, 0, 0, 1, 2],
 [2, 10, 1, 0, 6, 14, 66],
 [0, 1, 5, 0, 4, 5, 41],
 [1, 5, 1, 0, 5, 17, 70],
 [3, 5, 11, 0, 10, 16, 54],
 [2, 5, 4, 0, 7, 27, 54],
 [1, 3, 4, 0, 8, 15, 68]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 2 | Lambda2 = 2 | Accuracy = 0.2073")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Balanced Dataset: L=0.1

# %%
conf_matrix = np.array([
 [0, 4, 0, 0, 0, 2, 0],
 [0, 66, 0, 0, 0, 33, 0],
 [0, 33, 0, 0, 0, 23, 0],
 [0, 54, 0, 0, 0, 45, 0],
 [0, 35, 0, 0, 0, 64, 0],
 [0, 39, 0, 0, 0, 60, 0],
 [0, 56, 0, 0, 0, 43, 0]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 0.1 | Lambda2 = 0.1 | Accuracy = 0.2176")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Balanced Dataset: L=10

# %%
conf_matrix = np.array([
 [1, 3, 0, 0, 1, 0, 1],
 [2, 51, 0, 0, 19, 6, 21],
 [3, 20, 0, 0, 12, 8, 13],
 [2, 41, 0, 0, 24, 9, 23],
 [8, 22, 0, 0, 26, 12, 31],
 [5, 26, 0, 0, 20, 10, 38],
 [3, 32, 0, 0, 22, 14, 28]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 10 | Lambda2 = 10 | Accuracy = 0.2003")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Balanced Dataset: L=0.0001

# %%
conf_matrix = np.array([
 [0, 4, 0, 0, 0, 2, 0],
 [0, 63, 0, 0, 0, 36, 0],
 [0, 30, 0, 0, 0, 26, 0],
 [0, 54, 0, 0, 0, 45, 0],
 [0, 33, 0, 0, 0, 66, 0],
 [0, 38, 0, 0, 0, 61, 0],
 [0, 55, 0, 0, 0, 44, 0]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 10 | Lambda2 = 10 | Accuracy =0.214162")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Grid 5

# %% [markdown]
# ## Quantum-Like Signorino

# %% [markdown]
# ## Lambda = 1

# %%
conf_matrix = np.array([
 [0, 1, 3, 0, 0, 1, 1],
 [0, 50, 1, 0, 0, 24, 24],
 [2, 17, 5, 0, 0, 10, 22],
 [0, 45, 2, 0, 0, 22, 30],
 [5, 23, 5, 0, 0, 34, 32],
 [1, 28, 1, 0, 0, 40, 29],
 [0, 36, 4, 0, 0, 29, 30]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 1 | Lambda2 = 1 | Accuracy =0.215889")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lambda = 0.5

# %%
conf_matrix = np.array([
[1, 3, 1, 0, 0, 1, 0],
 [0, 64, 0, 0, 0, 35, 0],
 [4, 32, 2, 0, 0, 18, 0],
 [0, 54, 0, 0, 0, 45, 0],
 [4, 35, 3, 0, 0, 57, 0],
 [0, 36, 2, 0, 0, 60, 1],
 [2, 49, 3, 0, 0, 42, 3]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 0.5 | Lambda2 = 0.5 | Accuracy =0.224525")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lambda = 2

# %%
conf_matrix = np.array([
 [0, 0, 2, 0, 0, 1, 3],
 [0, 30, 1, 0, 0, 22, 46],
 [0, 12, 5, 0, 1, 7, 31],
 [1, 24, 2, 0, 0, 19, 53],
 [1, 10, 7, 0, 0, 30, 51],
 [2, 15, 2, 0, 1, 35, 44],
 [0, 19, 7, 0, 0, 24, 49]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 2 | Lambda2 = 2 | Accuracy = 0.205527")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lambda = 0.1

# %%
conf_matrix = np.array([
 [0, 3, 0, 0, 0, 3, 0],
 [0, 57, 0, 0, 0, 42, 0],
 [0, 29, 0, 0, 0, 27, 0],
 [0, 48, 0, 0, 0, 51, 0],
 [0, 33, 0, 0, 0, 66, 0],
 [0, 34, 0, 0, 0, 65, 0],
 [0, 50, 0, 0, 0, 49, 0]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 0.1 | Lambda2 = 0.1 | Accuracy = 0.210708")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lambda = 10

# %%
conf_matrix = np.array([
 [1, 0, 1, 0, 2, 0, 2],
 [2, 8, 0, 1, 25, 12, 51],
 [1, 1, 1, 1, 12, 7, 33],
 [0, 3, 0, 0, 26, 16, 54],
 [1, 5, 1, 0, 41, 15, 36],
 [1, 5, 0, 0, 38, 23, 32],
 [2, 6, 0, 2, 30, 12, 47]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 10 | Lambda2 = 10 | Accuracy = 0.208981")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lambda = 0.0001

# %%
conf_matrix = np.array([
 [0, 3, 0, 0, 0, 3, 0],
 [0, 54, 0, 0, 0, 45, 0],
 [0, 29, 0, 0, 0, 27, 0],
 [0, 45, 0, 0, 0, 54, 0],
 [0, 32, 0, 0, 0, 67, 0],
 [0, 34, 0, 0, 0, 65, 0],
 [0, 46, 0, 0, 0, 53, 0]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Signorino Model\nLambda1 = 0.0001 | Lambda2 = 0.0001 | Accuracy = 0.205527")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quantum-Like Normal Form

# %% [markdown]
# ### Lambda = 1

# %%
conf_matrix = np.array([
 [3, 2, 0, 0, 0, 1, 0],
 [12, 68, 0, 0, 0, 13, 6],
 [6, 40, 0, 0, 0, 5, 5],
 [15, 65, 0, 0, 0, 14, 5],
 [29, 48, 0, 0, 0, 16, 6],
 [18, 45, 0, 0, 0, 32, 4],
 [18, 63, 0, 0, 0, 14, 4]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Normal Form Model\nLambda1 = 1 | Lambda2 = 1 | Accuracy = 0.184801")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lambda = 0.5

# %%
conf_matrix = np.array([
 [3, 2, 0, 0, 0, 1, 0],
 [13, 71, 0, 0, 0, 14, 1],
 [9, 40, 0, 0, 0, 6, 1],
 [16, 66, 0, 0, 0, 16, 1],
 [33, 51, 0, 0, 0, 14, 1],
 [22, 43, 0, 0, 0, 33, 1],
 [19, 65, 0, 0, 0, 14, 1]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Normal Form Model\nLambda1 = 0.5 | Lambda2 = 0.5 | Accuracy = 0.186528")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lambda = 2

# %%
conf_matrix = np.array([
 [3, 2, 0, 0, 0, 1, 0],
 [12, 66, 0, 0, 0, 8, 13],
 [7, 32, 0, 0, 0, 6, 11],
 [15, 57, 0, 0, 0, 10, 17],
 [21, 47, 0, 0, 0, 12, 19],
 [19, 45, 0, 0, 0, 21, 14],
 [13, 51, 0, 0, 0, 14, 21]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Normal Form Model\nLambda1 = 2 | Lambda2 = 2 | Accuracy = 0.19171")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lambda = 0.1

# %%
conf_matrix = np.array([
 [3, 2, 0, 0, 0, 1, 0],
 [12, 73, 0, 0, 0, 14, 0],
 [11, 40, 0, 0, 0, 5, 0],
 [20, 66, 0, 0, 0, 13, 0],
 [38, 47, 0, 0, 0, 14, 0],
 [24, 45, 0, 0, 0, 30, 0],
 [19, 67, 0, 0, 0, 13, 0]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Normal Form Model\nLambda1 = 0.1 | Lambda2 = 0.1 | Accuracy = 0.183074")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lambda = 10

# %%
conf_matrix = np.array([
 [4, 1, 0, 0, 0, 0, 1],
 [17, 56, 0, 0, 0, 0, 26],
 [11, 19, 0, 0, 0, 4, 22],
 [19, 48, 0, 0, 0, 2, 30],
 [29, 25, 0, 0, 0, 4, 41],
 [37, 35, 0, 0, 0, 2, 25],
 [23, 37, 0, 0, 0, 1, 38]

])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Normal Form Model\nLambda1 = 10 | Lambda2 = 10 | Accuracy = 0.184801")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Lambda = 0.0001

# %%
conf_matrix = np.array([
 [4, 2, 0, 0, 0, 0, 0],
 [16, 57, 0, 0, 0, 26, 0],
 [12, 28, 0, 0, 0, 16, 0],
 [16, 61, 0, 0, 0, 22, 0],
 [30, 50, 0, 0, 0, 19, 0],
 [23, 47, 0, 0, 0, 29, 0],
 [23, 55, 0, 0, 0, 21, 0]
])

labels = ['ACQ1', 'ACQ2', 'CAP1', 'CAP2', 'NEGO', 'SQ', 'WAR1']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels, cbar=True)

plt.title("Quantum-Like Normal Form Model\nLambda1 = 0.0001 | Lambda2 = 0.0001 | Accuracy = 0.15544")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()
